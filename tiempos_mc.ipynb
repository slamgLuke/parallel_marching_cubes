# %%
threads = [2, 4, 8, 16, 32, 64, 128]

# precision = 10.0 / 512.0
# N = 512^3
for_times = [65.4, 38.4, 31.6, 26, 24.9, 25.6, 26.7]
task_times = [63.6, 35.5, 22.9, 20.1, 20.4, 20.1, 21.3]


# precision = 10.0 / 256.0
# N = 256^3
for_times = [8.83, 5.704, 4.735, 4.188, 4.057, 4.003, 5.796]
task_times = [13.262, 9.594, 12.268, 14.044, 14.123, 13.811, 14.876]

# precision = 10.0 / 128.0
# N = 128^3
for_times = [1.289, 0.878, 0.76, 0.688, 0.685, 0.709, 2.281]
task_times = [1.838, 1.467, 1.753, 1.865, 1.842, 1.925, 3.554]

# precision = 10.0 / 64.0
# N = 64^3
for_times = [0.223, 0.224, 0.174, 0.149, 0.149, 0.165, 1.373]
task_times = [0.276, 0.228, 0.26, 0.286, 0.304, 0.314, 0.329]

# precision = 10.0 / 32.0
# N = 32^3
for_times = [0.04, 0.041, 0.062, 0.04, 0.041, 0.06, 1.232]
task_times = [0.05, 0.05, 0.049, 0.051, 0.059, 0.067, 0.175]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definición de los threads
threads = np.array([2, 4, 8, 16, 32, 64, 128])

# Datos para diferentes precisiones / tamaños de problema (N)
data = {
    "N = $512^3$ (precision = 10.0 / 512.0)": {
        "for_times": [65.4, 38.4, 31.6, 26, 24.9, 25.6, 26.7]
    },
    "N = $256^3$ (precision = 10.0 / 256.0)": {
        "for_times": [8.83, 5.704, 4.735, 4.188, 4.057, 4.003, 5.796]
    },
    "N = $128^3$ (precision = 10.0 / 128.0)": {
        "for_times": [1.289, 0.878, 0.76, 0.688, 0.685, 0.709, 2.281]
    },
    "N = $64^3$ (precision = 10.0 / 64.0)": {
        "for_times": [0.223, 0.224, 0.174, 0.149, 0.149, 0.165, 1.373]
    },
    "N = $32^3$ (precision = 10.0 / 32.0)": {
        "for_times": [0.04, 0.041, 0.062, 0.04, 0.041, 0.06, 1.232]
    }
}

plt.figure(figsize=(10, 6))
colors = plt.cm.viridis(np.linspace(0, 1, len(data)))

for i, (label, values) in enumerate(data.items()):
    plt.plot(threads, values["for_times"],
             label=f'{label}',
             color=colors[i],
             marker='o')

plt.xlabel('Número de Threads')
plt.ylabel('Tiempo de Ejecución (segundos)')
plt.title('Tiempos de Ejecución: For Loop')
plt.xscale('log', base=2)
plt.yscale('log') # Escala logarítmica en el eje Y para mejor visualización de rangos amplios
plt.xticks(threads, [str(int(t)) for t in threads])
plt.grid(True, which="both", ls="--", c='0.7')
plt.legend(title='Tamaño del Problema', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definición de los threads
threads = np.array([2, 4, 8, 16, 32, 64, 128])

# Datos para diferentes precisiones / tamaños de problema (N)
data = {
    "N = $512^3$ (precision = 10.0 / 512.0)": {
        "task_times": [63.6, 35.5, 22.9, 20.1, 20.4, 20.1, 21.3]
    },
    "N = $256^3$ (precision = 10.0 / 256.0)": {
        "task_times": [13.262, 9.594, 12.268, 14.044, 14.123, 13.811, 14.876]
    },
    "N = $128^3$ (precision = 10.0 / 128.0)": {
        "task_times": [1.838, 1.467, 1.753, 1.865, 1.842, 1.925, 3.554]
    },
    "N = $64^3$ (precision = 10.0 / 64.0)": {
        "task_times": [0.276, 0.228, 0.26, 0.286, 0.304, 0.314, 0.329]
    },
    "N = $32^3$ (precision = 10.0 / 32.0)": {
        "task_times": [0.05, 0.05, 0.049, 0.051, 0.059, 0.067, 0.175]
    }
}

plt.figure(figsize=(10, 6))
colors = plt.cm.plasma(np.linspace(0, 1, len(data)))

for i, (label, values) in enumerate(data.items()):
    plt.plot(threads, values["task_times"],
             label=f'{label}',
             color=colors[i],
             marker='x')

plt.xlabel('Número de Threads')
plt.ylabel('Tiempo de Ejecución (segundos)')
plt.title('Tiempos de Ejecución: Tasks')
plt.xscale('log', base=2)
plt.yscale('log')
plt.xticks(threads, [str(int(t)) for t in threads])
plt.grid(True, which="both", ls="--", c='0.7')
plt.legend(title='Tamaño del Problema', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
